# %% [markdown]
# <a href="https://colab.research.google.com/github/Dewivania/Case-Study-1/blob/main/Projek%20UAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install Unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install contractions
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import warnings; warnings.simplefilter('ignore')
import nltk

try:
    import google.colab
    IN_COLAB = True
    # !wget https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/taudataDDGsna.py
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/contoh.pdf
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/slang.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/stopwords_id.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/stopwords_en.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/kata_dasar.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/wn-ind-def.tab
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/wn-msa-all.tab
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/ind_SA.csv
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/all_indo_man_tag_corpus_model.crf.tagger

    # !pip install --upgrade spacy python-crfsuite unidecode textblob sastrawi sklearn-pycrfsuite
    # !pip install --upgrade unidecode twython tweepy beautifulsoup4 tika
    # !python -m spacy download en
    # !python -m spacy download xx
    # !python -m spacy download en_core_web_sm
    nltk.download('popular')
except:
    IN_COLAB = False
    print("Running the code locally, please make sure all the python module versions agree with colab environment and all data/assets downloaded")
# Out:
# --2022-12-29 06:18:29--  https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/taudataDDGsna.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8030 (7.8K) [text/plain]
# Saving to: ‘taudataDDGsna.py.2’
#
# taudataDDGsna.py.2  100%[===================>]   7.84K  --.-KB/s    in 0s
#
# 2022-12-29 06:18:29 (23.9 MB/s) - ‘taudataDDGsna.py.2’ saved [8030/8030]
#
# mkdir: cannot create directory ‘data’: File exists
# --2022-12-29 06:18:30--  https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/contoh.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
try: # Running Locally, yakinkan "file_" berada di folder "data"
    df = pd.read_csv("data/data_search.csv", low_memory = False, encoding='utf8')
except: # Running in Google Colab
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/hafizaah0905/Project-UAS/main/data_search.csv
    df = pd.read_csv("data/data_search.csv", low_memory = False, encoding='utf8')

# %%
df.shape
# Out:
# (14000, 8)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Tanggal', 'Pengguna', 'Retweet', 'Likes', 'Source',
#        'Tweet', 'Sentimen'],
#       dtype='object')

# %%
# drop kolom yang tidak terpakai
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df['Tanggal'] = df['Tanggal'] .astype('datetime64')
df['Source'] = df['Source'] .astype('category')
df['Sentimen'] = df['Sentimen'] .astype('category')

# %%
df.dtypes
# Out:
# Tanggal     datetime64[ns]
# Pengguna            object
# Retweet              int64
# Likes                int64
# Source            category
# Tweet               object
# Sentimen          category
# dtype: object

# %%
df.isnull().sum()
# Out:
# Tanggal     0
# Pengguna    0
# Retweet     0
# Likes       0
# Source      0
# Tweet       0
# Sentimen    0
# dtype: int64

# %%
df
# Out:
#                   Tanggal         Pengguna  Retweet  Likes  \
# 0     2022-12-27 05:11:00       whoszahyra        0      0
# 1     2022-12-27 05:05:18        Box2boxID        0      1
# 2     2022-12-27 05:04:38         low_lowi        0      0
# 3     2022-12-27 04:58:17  Cowokco45874854        0      0
# 4     2022-12-27 04:58:11        reshadeco       22      0
# ...                   ...              ...      ...    ...
# 13995 2022-12-19 01:55:57       mozalelly_        0      0
# 13996 2022-12-19 01:55:56         Dnngblck     1034      0
# 13997 2022-12-19 01:55:55       user252729      343      0
# 13998 2022-12-19 01:55:54       Manusia4A_        0      0
# 13999 2022-12-19 01:55:52        shakiluvs       87      0
#
#                     Source                                              Tweet  \
# 0       Twitter for iPhone         btw gua gamon banget sama pildun ahajsgsja
# 1      Twitter for Android  Kapan yha? 😩 Tes dulu pas gelaran Pildun U-20 ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tanggal   14000 non-null  datetime64[ns]
#  1   Pengguna  14000 non-null  object
#  2   Retweet   14000 non-null  int64
#  3   Likes     14000 non-null  int64
#  4   Source    14000 non-null  category
#  5   Tweet     14000 non-null  object
#  6   Sentimen  14000 non-null  category
# dtypes: category(2), datetime64[ns](1), int64(2), object(2)
# memory usage: 575.9+ KB

# %% [markdown]
# ## prepocessing data

# %% [markdown]
# Normalisasi data terlebih dahulu

# %%
import pandas as pd
import emoji
import contractions
import re

# %%
def cleansing(Tweet):
  #replace RT
  t1 = re.sub(r'^RT[\s]+', '', Tweet)
  #replace @_username
  t2 = re.sub('\B@\w+','', t1)
  #replace emoji
  t3 = emoji.demojize(t2)
  #replace URL (http:// or https:\\)
  t4 = re.sub('(http|https):\/\/\s+','', t3)
  #replace #_something_
  t5 = re.sub('#+','', t4)
  #lower case each letter
  t6 = t5.lower()
  #replace word repetition with a single occurance ('ooooooo' becomes 'oo)
  t7 = re.sub(r'(.)\1+', r'1\1', t6)
  #replace punctuation repetition with a single occurance ('!!!!!' becomes '!)
  t8 = re.sub(r'[\?\.\!]+(?=[\?.\!])','', t7)
  # Alphabets only, exclude numbers and special characters
  t9 = re.sub(r'[^a-zA-Z]',' ', t8)
  #replace contractions with their extended forms
  t10 = contractions.fix(t9)
  return t10

# %%
df =  pd.read_csv("data/data_search.csv", low_memory = False, encoding='utf8')
df
# Out:
#        Unnamed: 0                    Tanggal         Pengguna  Retweet  Likes  \
# 0               0  2022-12-27 05:11:00+00:00       whoszahyra        0      0
# 1               1  2022-12-27 05:05:18+00:00        Box2boxID        0      1
# 2               2  2022-12-27 05:04:38+00:00         low_lowi        0      0
# 3               3  2022-12-27 04:58:17+00:00  Cowokco45874854        0      0
# 4               4  2022-12-27 04:58:11+00:00        reshadeco       22      0
# ...           ...                        ...              ...      ...    ...
# 13995       13995  2022-12-19 01:55:57+00:00       mozalelly_        0      0
# 13996       13996  2022-12-19 01:55:56+00:00         Dnngblck     1034      0
# 13997       13997  2022-12-19 01:55:55+00:00       user252729      343      0
# 13998       13998  2022-12-19 01:55:54+00:00       Manusia4A_        0      0
# 13999       13999  2022-12-19 01:55:52+00:00        shakiluvs       87      0
#
# ...

# %%
for i, r in df.iterrows():
    y = cleansing(r['Tweet'])
    df.loc[i, 'Tweet'] = y

df.head()
# Out:
#    Unnamed: 0                    Tanggal         Pengguna  Retweet  Likes  \
# 0           0  2022-12-27 05:11:00+00:00       whoszahyra        0      0
# 1           1  2022-12-27 05:05:18+00:00        Box2boxID        0      1
# 2           2  2022-12-27 05:04:38+00:00         low_lowi        0      0
# 3           3  2022-12-27 04:58:17+00:00  Cowokco45874854        0      0
# 4           4  2022-12-27 04:58:11+00:00        reshadeco       22      0
#
#                 Source                                              Tweet  \
# 0   Twitter for iPhone  by the way gua gamon banget sama pildun ahajsgsja
# 1  Twitter for Android  kapan yha   weary face  tes dulu pas gelaran p...
# 2      Twitter Web App  wow  peringkat    level dunia  tin gal timnas ...
# 3  Twitter for Android                  iyadeh iya dodogy yg juara pildun
# 4   Twitter for iPhone    cody gakpo awalnya dekat dengan manchester u...
#
#   Sentimen
# 0   Netral
# 1   Netral
# 2  Positif
# 3   Netral
# 4   Netral

# %% [markdown]
# ## Tokenisasi

# %%
from nltk.tokenize import word_tokenize

# %%
def token_stop_pos(text):
  tags = pos_tag(word_tokenize(text))
  newlist = []
  for word, tag in tags:
    if word.lower() not in set(stopwords.words('english')):
      newlist.append(tuple([word, pos_dict.get(tag[0])]))
  return newlist

# %% [markdown]
# ## Lematisasi
